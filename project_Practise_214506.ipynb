# %% [markdown]
# <a href="https://colab.research.google.com/github/ramtheking/group_project_ram/blob/main/project_Practise_214506.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
dates = pd.date_range('20130101 ', periods=6)
print (dates)
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
s = pd.Series([1,3,5,np. nan,6,8])
print (s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.964478  0.609891 -0.023372 -0.923121
# 2013-01-02  0.206383 -1.079295  0.261897  0.263779
# 2013-01-03 -0.979195  0.376346 -1.784139 -0.949033
# 2013-01-04 -1.797672  1.072604 -1.087044  0.655412
# 2013-01-05  1.165157  1.385572  0.140096  0.442101
# 2013-01-06  1.030600 -0.224325 -0.658316 -0.638250

# %%
df2 = pd.DataFrame({ ' A ' : 1.,
 ' B  ': pd.Timestamp('  20130102  '),
 ' C  ': pd.Series(1,index=list(range(4))),
 ' D ': np.array([3] * 4),
 ' E  ': pd.Categorical([" test "," train "," test "," train "]),
 ' F  ': ' foo'  })
print(df2)
# Out:
#     A         B     C     D       E     F
# 0  1.0 2013-01-02     1    3    test    foo
# 1  1.0 2013-01-02     1    3   train    foo
# 2  1.0 2013-01-02     1    3    test    foo
# 3  1.0 2013-01-02     1    3   train    foo

# %%
df2.dtypes
# Out:
#  A             float64
#  B      datetime64[ns]
#  C               int64
#  D               int64
#  E            category
#  F              object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.964478  0.609891 -0.023372 -0.923121
# 2013-01-02  0.206383 -1.079295  0.261897  0.263779
# 2013-01-03 -0.979195  0.376346 -1.784139 -0.949033
# 2013-01-04 -1.797672  1.072604 -1.087044  0.655412
# 2013-01-05  1.165157  1.385572  0.140096  0.442101

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.098292  0.356799 -0.525146 -0.191519
# std    1.226786  0.898361  0.804026  0.725906
# min   -1.797672 -1.079295 -1.784139 -0.949033
# 25%   -0.682800 -0.074157 -0.979862 -0.851903
# 50%    0.585430  0.493118 -0.340844 -0.187235
# 75%    1.014069  0.956926  0.099229  0.397521
# max    1.165157  1.385572  0.261897  0.655412

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.964478    0.206383   -0.979195   -1.797672    1.165157    1.030600
# B    0.609891   -1.079295    0.376346    1.072604    1.385572   -0.224325
# C   -0.023372    0.261897   -1.784139   -1.087044    0.140096   -0.658316
# D   -0.923121    0.263779   -0.949033    0.655412    0.442101   -0.638250

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01  0.964478  0.609891 -0.023372 -0.923121
# 2013-01-02  0.206383 -1.079295  0.261897  0.263779
# 2013-01-03 -0.979195  0.376346 -1.784139 -0.949033
# 2013-01-04 -1.797672  1.072604 -1.087044  0.655412
# 2013-01-05  1.165157  1.385572  0.140096  0.442101
# 2013-01-06  1.030600 -0.224325 -0.658316 -0.638250

# %%
df.sort_values(by='C')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.979195  0.376346 -1.784139 -0.949033
# 2013-01-04 -1.797672  1.072604 -1.087044  0.655412
# 2013-01-06  1.030600 -0.224325 -0.658316 -0.638250
# 2013-01-01  0.964478  0.609891 -0.023372 -0.923121
# 2013-01-05  1.165157  1.385572  0.140096  0.442101
# 2013-01-02  0.206383 -1.079295  0.261897  0.263779

# %%
df.loc[dates[3]]
# Out:
# A   -1.797672
# B    1.072604
# C   -1.087044
# D    0.655412
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.at[dates[1],'B']
# Out:
# -1.0792951204358594

# %%
df.iloc[3]
# Out:
# A   -1.797672
# B    1.072604
# C   -1.087044
# D    0.655412
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iat[1,1]
# Out:
# -1.0792951204358594

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.964478  0.609891       NaN       NaN
# 2013-01-02  0.206383       NaN  0.261897  0.263779
# 2013-01-03       NaN  0.376346       NaN       NaN
# 2013-01-04       NaN  1.072604       NaN  0.655412
# 2013-01-05  1.165157  1.385572  0.140096  0.442101
# 2013-01-06  1.030600       NaN       NaN       NaN

# %%
df[df < 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN -0.023372 -0.923121
# 2013-01-02       NaN -1.079295       NaN       NaN
# 2013-01-03 -0.979195       NaN -1.784139 -0.949033
# 2013-01-04 -1.797672       NaN -1.087044       NaN
# 2013-01-05       NaN       NaN       NaN       NaN
# 2013-01-06       NaN -0.224325 -0.658316 -0.638250

# %%
df2 = df.copy()
df2['E'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.964478  0.609891 -0.023372 -0.923121    one
# 2013-01-02  0.206383 -1.079295  0.261897  0.263779    one
# 2013-01-03 -0.979195  0.376346 -1.784139 -0.949033    two
# 2013-01-04 -1.797672  1.072604 -1.087044  0.655412  three
# 2013-01-05  1.165157  1.385572  0.140096  0.442101   four
# 2013-01-06  1.030600 -0.224325 -0.658316 -0.638250  three

# %%
df2[df2['E'].isin(['two','four'])]
#printing the particular row based on coloums output
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.979195  0.376346 -1.784139 -0.949033   two
# 2013-01-05  1.165157  1.385572  0.140096  0.442101  four

# %%
df.at[dates[0],'A'] = 0

# %%
df.iat[0,1] = 0

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.023372 -5
# 2013-01-02 -0.206383 -1.079295 -0.261897 -5
# 2013-01-03 -0.979195 -0.376346 -1.784139 -5
# 2013-01-04 -1.797672 -1.072604 -1.087044 -5
# 2013-01-05 -1.165157 -1.385572 -0.140096 -5
# 2013-01-06 -1.030600 -0.224325 -0.658316 -5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.023372  5
# 2013-01-02  0.206383 -1.079295  0.261897  5
# 2013-01-03 -0.979195  0.376346 -1.784139  5
# 2013-01-04 -1.797672  1.072604 -1.087044  5
# 2013-01-05  1.165157  1.385572  0.140096  5
# 2013-01-06  1.030600 -0.224325 -0.658316  5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df
# Out:
#                    A         B         C  D
# 2013-01-01  0.000000  0.000000 -0.023372  5
# 2013-01-02  0.206383 -1.079295  0.261897  5
# 2013-01-03 -0.979195  0.376346 -1.784139  5
# 2013-01-04 -1.797672  1.072604 -1.087044  5
# 2013-01-05  1.165157  1.385572  0.140096  5
# 2013-01-06  1.030600 -0.224325 -0.658316  5

# %%
 pd.isnull(df1)
# Out:
#                 A      B      C      D      E
# 2013-01-01  False  False  False  False  False
# 2013-01-02  False  False  False  False  False
# 2013-01-03  False  False  False  False   True
# 2013-01-04  False  False  False  False   True

# %%
df.sub(s, axis='index')
# Out:
#                       A   B   C   D
# 2013-01-01 00:00:00 NaN NaN NaN NaN
# 2013-01-02 00:00:00 NaN NaN NaN NaN
# 2013-01-03 00:00:00 NaN NaN NaN NaN
# 2013-01-04 00:00:00 NaN NaN NaN NaN
# 2013-01-05 00:00:00 NaN NaN NaN NaN
# 2013-01-06 00:00:00 NaN NaN NaN NaN
# 0                   NaN NaN NaN NaN
# 1                   NaN NaN NaN NaN
# 2                   NaN NaN NaN NaN
# 3                   NaN NaN NaN NaN
# 4                   NaN NaN NaN NaN
# 5                   NaN NaN NaN NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2013-01-01  0.000000  0.000000 -0.023372   5
# 2013-01-02  0.206383 -1.079295  0.238525  10
# 2013-01-03 -0.772811 -0.702949 -1.545614  15
# 2013-01-04 -2.570483  0.369655 -2.632658  20
# 2013-01-05 -1.405327  1.755226 -2.492562  25
# 2013-01-06 -0.374727  1.530902 -3.150878  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.962829
# B    2.464867
# C    2.046036
# D    0.000000
# dtype: float64

# %%
 s.value_counts()
# Out:
# 1.0    1
# 3.0    1
# 5.0    1
# 6.0    1
# 8.0    1
# dtype: int64

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.796171  1.091162 -0.698630 -0.274066
# 1 -0.406751  1.565917  0.204289 -0.936507
# 2 -1.092216  0.777059 -0.181953  0.467310
# 3 -1.507220  0.121970 -0.646421  0.346489
# 4 -0.711798 -1.918863  0.977269 -0.194818
# 5 -0.384317  0.707165 -0.421010 -0.769682
# 6 -0.729046  1.217498  0.275067  0.364654
# 7 -0.249889  1.757504 -0.976423  0.388038
# 8  0.658557 -0.519392 -0.111633  2.352568
# 9  1.304042  0.168330 -1.862635  1.169359

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
left
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.566719  1.488448 -0.275800  0.461839
# 1  0.262753 -0.325816 -0.916590  0.672916
# 2 -0.258965 -0.699884  0.333984  0.586244
# 3 -0.395406 -1.209795  0.345957  1.747476
# 4  0.680352 -0.241731  1.384424  1.823429
# 5  0.348590 -1.326736 -0.900111 -0.736699
# 6  0.445756 -1.911033  0.321147 -0.346719
# 7 -0.475082  0.830516  1.072122 -1.387805

# %%
df.groupby('B').sum()
#knowing the sum of individuals
# Out:
#                   A         C         D
# B
# -1.911033  0.445756  0.321147 -0.346719
# -1.326736  0.348590 -0.900111 -0.736699
# -1.209795 -0.395406  0.345957  1.747476
# -0.699884 -0.258965  0.333984  0.586244
# -0.325816  0.262753 -0.916590  0.672916
# -0.241731  0.680352  1.384424  1.823429
#  0.830516 -0.475082  1.072122 -1.387805
#  1.488448  0.566719 -0.275800  0.461839

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]))

index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df2 = df[0:8]
df2
#to know the sum of 2 grops completly
# Out:
#                      A         B
# first second
# bar   one     0.304789  0.759968
#       two    -1.193809 -0.686156
# baz   one    -2.797692 -0.931938
#       two     1.210937  1.009353
# foo   one     1.303392 -1.383539
#       two    -1.493120  0.990661
# qux   one     0.597299  0.841297
#       two    -0.650325  0.076556

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.304789
#                B    0.759968
#        two     A   -1.193809
#                B   -0.686156
# baz    one     A   -2.797692
#                B   -0.931938
#        two     A    1.210937
#                B    1.009353
# foo    one     A    1.303392
#                B   -1.383539
#        two     A   -1.493120
#                B    0.990661
# qux    one     A    0.597299
#                B    0.841297
#        two     A   -0.650325
#                B    0.076556
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.304789  0.759968
#       two    -1.193809 -0.686156
# baz   one    -2.797692 -0.931938
#       two     1.210937  1.009353
# foo   one     1.303392 -1.383539
#       two    -1.493120  0.990661
# qux   one     0.597299  0.841297
#       two    -0.650325  0.076556

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-edb969d5a66a> in <module>()
# ----> 1 pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     104         margins_name,
#     105         observed,
# --> 106         sort,
#     107     )
#     108     return table.__finalize__(data, method="pivot_table")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     139         for i in values:
#     140             if i not in data:
# --> 141                 raise KeyError(i)
#     142
#     143         to_filter = []
#
# KeyError: 'D'

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min')
ts
# Out:
# 2012-01-01 00:00:00    363
# 2012-01-01 00:00:01    153
# 2012-01-01 00:00:02     79
# 2012-01-01 00:00:03    109
# 2012-01-01 00:00:04    159
#                       ...
# 2012-01-01 00:01:35    441
# 2012-01-01 00:01:36    265
# 2012-01-01 00:01:37    144
# 2012-01-01 00:01:38    236
# 2012-01-01 00:01:39    155
# Freq: S, Length: 100, dtype: int64

# %%
rng = pd.date_range('1/1/2012', periods=5)
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-01   -0.160084
# 2012-01-02    0.259459
# 2012-01-03   -0.302213
# 2012-01-04   -0.118317
# 2012-01-05    0.956597
# Freq: D, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)

#ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990Q1   -0.681079
# 1990Q2   -0.485641
# 1990Q3   -1.013139
# 1990Q4   -0.767551
# 1991Q1   -0.695001
# Freq: Q-NOV, dtype: float64

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a','c','c']})
print(df,end="\n")
print("\n")
df.dtypes
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         c
# 5   6         c
# id            int64
# raw_grade    object
# dtype: object

# %%
names = ["harshit" , "sankalp" , "ram", "karthik" , "shanmukha" , "kishen" ]
df.insert(loc = 0 , column = "names" , value = names)
df
# Out:
#        names  id raw_grade
# 0    harshit   1         a
# 1    sankalp   2         b
# 2        ram   3         b
# 3    karthik   4         a
# 4  shanmukha   5         c
# 5     kishen   6         c

# %%
df["grade"] = df["raw_grade"].astype("string")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    c
# 5    c
# Name: grade, dtype: string

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods = 1000))
ts = ts.cumsum()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.plot()

# %%
df.to_csv("project.csv")

# %%
f.to_excel("project.xlsx" , sheet_name = "project")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-853d9ea773ff> in <module>()
# ----> 1 f.to_excel("project.xlsx" , sheet_name = "project")
#
# NameError: name 'f' is not defined
